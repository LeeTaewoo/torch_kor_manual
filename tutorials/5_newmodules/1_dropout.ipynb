-- %%
require 'nn'
require 'DropoutEx'
require 'image'

-- %%
n = nn.DropoutEx(0.5)

-- %%
i = image.lena()

-- %%
result = n:forward(i)

-- %%
print('original image:')
itorch.image(i)
print('result image:')
itorch.image(result)
-- Out:
-- original image:
-- Console does not support images
-- result image:
-- Console does not support images

-- %%
mse = i:dist(result)
print('mse between original imgae and dropout-processed image: ' .. mse)
-- Out:
-- mse between original imgae and dropout-processed image: 378.37847723395
